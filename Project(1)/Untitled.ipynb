# %%
import shutil

folder_to_zip = "Project(1)"      
output_zip = "Project(1).zip"     

shutil.make_archive(folder_to_zip, 'zip', folder_to_zip)

output_zip
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 6
#       3 folder_to_zip = "Project(1)"
#       4 output_zip = "Project(1).zip"
# ----> 6 shutil.make_archive(folder_to_zip, 'zip', folder_to_zip)
#       8 output_zip
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\shutil.py:1171, in make_archive(base_name, format, root_dir, base_dir, verbose, dry_run, owner, group, logger)
#    1169 save_cwd = None
#    1170 if root_dir is not None:
# -> 1171     stmd = os.stat(root_dir).st_mode
#    1172     if not stat.S_ISDIR(stmd):
#    1173         raise NotADirectoryError(errno.ENOTDIR, 'Not a directory', root_dir)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'Project(1)'

# %%
import os

os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Dockerfile',
#  'export_model.py',
#  'main.py',
#  'Project(1).py',
#  'requirements.txt',
#  'titanic_model.pkl',
#  'Untitled.ipynb']

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df= pd.read_csv(" https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv")

# %%
df.head().T
# Out:
#                                    0                  1                  2  \
# engine_displacement              170                130                170
# num_cylinders                    3.0                5.0                NaN
# horsepower                     159.0               97.0               78.0
# vehicle_weight           3413.433759        3149.664934        3079.038997
# acceleration                    17.7               17.8               15.1
# model_year                      2003               2007               2018
# origin                        Europe                USA             Europe
# fuel_type                   Gasoline           Gasoline           Gasoline
# drivetrain           All-wheel drive  Front-wheel drive  Front-wheel drive
# num_doors                        0.0                0.0                0.0
# fuel_efficiency_mpg        13.231729          13.688217          14.246341
#
#                                    3                4
# engine_displacement              220              210
# num_cylinders                    4.0              1.0
# horsepower                       NaN            140.0
# vehicle_weight           2542.392402       3460.87099
# acceleration                    20.2             14.4
# model_year                      2009             2009
# origin                           USA           Europe
# fuel_type                     Diesel         Gasoline
# drivetrain           All-wheel drive  All-wheel drive
# num_doors                        2.0              2.0
# fuel_efficiency_mpg        16.912736        12.488369

# %%
df.isnull().sum()
# Out:
# engine_displacement      0
# num_cylinders          482
# horsepower             708
# vehicle_weight           0
# acceleration           930
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors              502
# fuel_efficiency_mpg      0
# dtype: int64

# %%
df.dtypes
# Out:
# engine_displacement      int64
# num_cylinders          float64
# horsepower             float64
# vehicle_weight         float64
# acceleration           float64
# model_year               int64
# origin                  object
# fuel_type               object
# drivetrain              object
# num_doors              float64
# fuel_efficiency_mpg    float64
# dtype: object

# %%
df[df.select_dtypes(include='number').columns] = df.select_dtypes(include='number').fillna(0.0)

# %%
df.isnull().sum()
# Out:
# engine_displacement    0
# num_cylinders          0
# horsepower             0
# vehicle_weight         0
# acceleration           0
# model_year             0
# origin                 0
# fuel_type              0
# drivetrain             0
# num_doors              0
# fuel_efficiency_mpg    0
# dtype: int64

# %%
df_full_train, df_test = train_test_split(df, test_size = 0.2, random_state = 1)
df_train, df_val = train_test_split(df_full_train, test_size = 0.25, random_state = 1)

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeRegressor

# %%
X_train= df_train.drop(columns=['fuel_efficiency_mpg'])
X_test= df_test.drop(columns=['fuel_efficiency_mpg'])
X_val= df_val.drop(columns=['fuel_efficiency_mpg'])

# %%
X_train_dicts = X_train.to_dict(orient='records')
X_val_dicts = X_val.to_dict(orient='records')
X_test_dicts = X_test.to_dict(orient='records')

# %%
vec = DictVectorizer(sparse=False)

X_train_vec = vec.fit_transform(X_train_dicts)
X_val_vec = vec.transform(X_val_dicts)
X_test_vec= vec.transform(X_test_dicts)

# %% [markdown]
# ## Question 1

# %%
features = ['vehicle_weight', 'model_year', 'origin']
X_train = df_train[features]
y_train = df_train['fuel_efficiency_mpg']

# %%
dt = DecisionTreeRegressor(max_depth=1)
dt.fit(X_train_vec, y_train)
# Out:
# DecisionTreeRegressor(max_depth=1)

# %%
feature_names = vec.get_feature_names_out()
importance = dt.feature_importances_

top_feature_index = np.argmax(importance)
print("Feature used for splitting:", feature_names[top_feature_index])
# Out:
# Feature used for splitting: vehicle_weight

# %% [markdown]
# ## Question 2

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
y_val = df_val['fuel_efficiency_mpg']
X_train = df_train.drop(columns=['fuel_efficiency_mpg'])

# %%
rf = RandomForestRegressor(
    n_estimators=10,
    random_state=1,
    n_jobs=-1
)
rf.fit(X_train_vec, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, n_jobs=-1, random_state=1)

# %%
y_pred = rf.predict(X_val_vec)

# %%
rmse = np.sqrt(mean_squared_error(y_val, y_pred))
print("RMSE:", rmse)
# Out:
# RMSE: 0.4599777557336148

# %% [markdown]
# ## Question 3

# %%
rmse_values = {}

# %%
for n in range(10, 201, 10):
    rf = RandomForestRegressor(
        n_estimators=n,
        random_state=1,
        n_jobs=-1
    )
    rf.fit(X_train_vec, y_train)
    y_pred = rf.predict(X_val_vec)
    rmse = np.sqrt(mean_squared_error(y_val, y_pred))
    rmse_values[n] = rmse
    print(f"n_estimators={n}: RMSE={rmse:.3f}")
# Out:
# n_estimators=10: RMSE=0.460
# n_estimators=20: RMSE=0.454
# n_estimators=30: RMSE=0.451
# n_estimators=40: RMSE=0.448
# n_estimators=50: RMSE=0.446
# n_estimators=60: RMSE=0.445
# n_estimators=70: RMSE=0.445
# n_estimators=80: RMSE=0.445
# n_estimators=90: RMSE=0.445
# n_estimators=100: RMSE=0.444
# n_estimators=110: RMSE=0.443
# n_estimators=120: RMSE=0.444
# n_estimators=130: RMSE=0.443
# n_estimators=140: RMSE=0.443
# n_estimators=150: RMSE=0.443
# n_estimators=160: RMSE=0.443
# n_estimators=170: RMSE=0.443
# n_estimators=180: RMSE=0.442
# n_estimators=190: RMSE=0.443
# n_estimators=200: RMSE=0.443

# %% [markdown]
# ### The answer is 200

# %% [markdown]
# ## Question 4

# %%
max_depth_values = [10, 15, 20, 25]
n_estimators_values = range(10, 201, 10)
results={}

# %%
for depth in max_depth_values:
    rmse_list = []
    for n in n_estimators_values:
        rf = RandomForestRegressor(
            n_estimators=n,
            max_depth=depth,
            random_state=1,
            n_jobs=-1
        )
        rf.fit(X_train_vec, y_train)
        y_pred = rf.predict(X_val_vec)
        rmse = np.sqrt(mean_squared_error(y_val, y_pred))
        rmse_list.append(rmse)
    results[depth] = np.mean(rmse_list)
    print(f"max_depth={depth}: mean RMSE={np.mean(rmse_list):.3f}")
# Out:
# max_depth=10: mean RMSE=0.442
# max_depth=15: mean RMSE=0.445
# max_depth=20: mean RMSE=0.446
# max_depth=25: mean RMSE=0.446

# %%
best_depth = min(results, key=results.get)
print(f"\n✅ Best max_depth = {best_depth}, Mean RMSE = {results[best_depth]:.3f}")
# Out:
# ✅ Best max_depth = 10, Mean RMSE = 0.442

# %% [markdown]
# ## Question 5

# %%
X_model=df[['vehicle_weight','horsepower','acceleration','engine_displacement']]

# %%
model = RandomForestRegressor(
    n_estimators = 10,
    max_depth = 20,
    random_state = 1,
    n_jobs = -1
)
model.fit(X_train_vec, y_train)
# Out:
# RandomForestRegressor(max_depth=20, n_estimators=10, n_jobs=-1, random_state=1)

# %%
importances = model.feature_importances_
for name, importance in zip(X_model.columns, importances):
    print(f"{name}: {importance:.4f}")
# Out:
# vehicle_weight: 0.0115
# horsepower: 0.0004
# acceleration: 0.0003
# engine_displacement: 0.0033

# %%
most_important = feature_names[importances.argmax()]
print("\nMost important feature:", most_important)
# Out:
# Most important feature: vehicle_weight

# %% [markdown]
# ## Question 6

# %%
import xgboost as xgb

# %%
dtrain = xgb.DMatrix(X_train_vec, label=y_train)
dval = xgb.DMatrix(X_val_vec, label=y_val)

# %%
watchlist = [(dtrain, 'train'), (dval, 'validation')]

# %%
xgb_params = {
    'eta': 0.3,
    'max_depth': 6,
    'min_child_weight': 1,
    'objective': 'reg:squarederror',
    'nthread': 8,
    'seed': 1,
    'verbosity': 1,
}

# %%
model = xgb.train(
    params=xgb_params,
    dtrain=dtrain,
    num_boost_round=100,
    evals=watchlist
)
# Out:
# [0]	train-rmse:1.81393	validation-rmse:1.85444
# [1]	train-rmse:1.31919	validation-rmse:1.35353
# [2]	train-rmse:0.98120	validation-rmse:1.01316
# [3]	train-rmse:0.75443	validation-rmse:0.78667
# [4]	train-rmse:0.60680	validation-rmse:0.64318
# [5]	train-rmse:0.51381	validation-rmse:0.55664
# [6]	train-rmse:0.45470	validation-rmse:0.50321
# [7]	train-rmse:0.41881	validation-rmse:0.47254
# [8]	train-rmse:0.39534	validation-rmse:0.45509
# [9]	train-rmse:0.38038	validation-rmse:0.44564
# [10]	train-rmse:0.37115	validation-rmse:0.43896
# [11]	train-rmse:0.36361	validation-rmse:0.43594
# [12]	train-rmse:0.35850	validation-rmse:0.43558
# [13]	train-rmse:0.35365	validation-rmse:0.43394
# [14]	train-rmse:0.35025	validation-rmse:0.43349
# [15]	train-rmse:0.34666	validation-rmse:0.43362
# [16]	train-rmse:0.34459	validation-rmse:0.43378
# [17]	train-rmse:0.34128	validation-rmse:0.43405
# [18]	train-rmse:0.33822	validation-rmse:0.43391
# [19]	train-rmse:0.33709	validation-rmse:0.43374
# [20]	train-rmse:0.33553	validation-rmse:0.43376
# [21]	train-rmse:0.33243	validation-rmse:0.43453
# [22]	train-rmse:0.33031	validation-rmse:0.43510
# [23]	train-rmse:0.32815	validation-rmse:0.43601
# [24]	train-rmse:0.32670	validation-rmse:0.43592
# [25]	train-rmse:0.32268	validation-rmse:0.43683
# [26]	train-rmse:0.32085	validation-rmse:0.43678
# [27]	train-rmse:0.32035	validation-rmse:0.43681
# [28]	train-rmse:0.31879	validation-rmse:0.43719
# [29]	train-rmse:0.31653	validation-rmse:0.43739
# [30]	train-rmse:0.31475	validation-rmse:0.43752
# [31]	train-rmse:0.31392	validation-rmse:0.43782
# [32]	train-rmse:0.31263	validation-rmse:0.43761
# [33]	train-rmse:0.31155	validation-rmse:0.43764
# [34]	train-rmse:0.31054	validation-rmse:0.43793
# [35]	train-rmse:0.30960	validation-rmse:0.43784
# [36]	train-rmse:0.30813	validation-rmse:0.43828
# [37]	train-rmse:0.30573	validation-rmse:0.43891
# [38]	train-rmse:0.30406	validation-rmse:0.43924
# [39]	train-rmse:0.30257	validation-rmse:0.43946
# [40]	train-rmse:0.30202	validation-rmse:0.43968
# [41]	train-rmse:0.29908	validation-rmse:0.43978
# [42]	train-rmse:0.29772	validation-rmse:0.43998
# [43]	train-rmse:0.29594	validation-rmse:0.43969
# [44]	train-rmse:0.29420	validation-rmse:0.44009
# [45]	train-rmse:0.29126	validation-rmse:0.44024
# [46]	train-rmse:0.28929	validation-rmse:0.44041
# [47]	train-rmse:0.28821	validation-rmse:0.44101
# [48]	train-rmse:0.28629	validation-rmse:0.44096
# [49]	train-rmse:0.28528	validation-rmse:0.44142
# [50]	train-rmse:0.28456	validation-rmse:0.44140
# [51]	train-rmse:0.28309	validation-rmse:0.44160
# [52]	train-rmse:0.28144	validation-rmse:0.44109
# [53]	train-rmse:0.28095	validation-rmse:0.44152
# [54]	train-rmse:0.27894	validation-rmse:0.44191
# [55]	train-rmse:0.27618	validation-rmse:0.44225
# [56]	train-rmse:0.27373	validation-rmse:0.44265
# [57]	train-rmse:0.27156	validation-rmse:0.44310
# [58]	train-rmse:0.26938	validation-rmse:0.44276
# [59]	train-rmse:0.26797	validation-rmse:0.44282
# [60]	train-rmse:0.26768	validation-rmse:0.44290
# [61]	train-rmse:0.26749	validation-rmse:0.44285
# [62]	train-rmse:0.26536	validation-rmse:0.44311
# [63]	train-rmse:0.26420	validation-rmse:0.44329
# [64]	train-rmse:0.26236	validation-rmse:0.44360
# [65]	train-rmse:0.26174	validation-rmse:0.44352
# [66]	train-rmse:0.26155	validation-rmse:0.44360
# [67]	train-rmse:0.25959	validation-rmse:0.44410
# [68]	train-rmse:0.25719	validation-rmse:0.44487
# [69]	train-rmse:0.25665	validation-rmse:0.44476
# [70]	train-rmse:0.25489	validation-rmse:0.44531
# [71]	train-rmse:0.25277	validation-rmse:0.44563
# [72]	train-rmse:0.25084	validation-rmse:0.44632
# [73]	train-rmse:0.25017	validation-rmse:0.44649
# [74]	train-rmse:0.24985	validation-rmse:0.44661
# [75]	train-rmse:0.24792	validation-rmse:0.44628
# [76]	train-rmse:0.24643	validation-rmse:0.44671
# [77]	train-rmse:0.24565	validation-rmse:0.44667
# [78]	train-rmse:0.24421	validation-rmse:0.44633
# [79]	train-rmse:0.24291	validation-rmse:0.44663
# [80]	train-rmse:0.24254	validation-rmse:0.44689
# [81]	train-rmse:0.24246	validation-rmse:0.44692
# [82]	train-rmse:0.24112	validation-rmse:0.44705
# [83]	train-rmse:0.23963	validation-rmse:0.44721
# [84]	train-rmse:0.23803	validation-rmse:0.44704
# [85]	train-rmse:0.23644	validation-rmse:0.44749
# [86]	train-rmse:0.23533	validation-rmse:0.44757
# [87]	train-rmse:0.23481	validation-rmse:0.44756
# [88]	train-rmse:0.23428	validation-rmse:0.44778
# [89]	train-rmse:0.23267	validation-rmse:0.44809
# [90]	train-rmse:0.23193	validation-rmse:0.44839
# [91]	train-rmse:0.23149	validation-rmse:0.44844
# [92]	train-rmse:0.23040	validation-rmse:0.44863
# [93]	train-rmse:0.22891	validation-rmse:0.44896
# [94]	train-rmse:0.22701	validation-rmse:0.44922
# [95]	train-rmse:0.22475	validation-rmse:0.44904
# [96]	train-rmse:0.22336	validation-rmse:0.44954
# [97]	train-rmse:0.22131	validation-rmse:0.44979
# [98]	train-rmse:0.22013	validation-rmse:0.45040
# [99]	train-rmse:0.21950	validation-rmse:0.45018

# %%
xgb_params['eta'] = 0.1

# %%
model_low_eta = xgb.train(
    params=xgb_params,
    dtrain=dtrain,
    num_boost_round=100,
    evals=watchlist
)
# Out:
# [0]	train-rmse:1.81393	validation-rmse:1.85444
# [1]	train-rmse:1.31919	validation-rmse:1.35353
# [2]	train-rmse:0.98120	validation-rmse:1.01316
# [3]	train-rmse:0.75443	validation-rmse:0.78667
# [4]	train-rmse:0.60680	validation-rmse:0.64318
# [5]	train-rmse:0.51381	validation-rmse:0.55664
# [6]	train-rmse:0.45470	validation-rmse:0.50321
# [7]	train-rmse:0.41881	validation-rmse:0.47254
# [8]	train-rmse:0.39534	validation-rmse:0.45509
# [9]	train-rmse:0.38038	validation-rmse:0.44564
# [10]	train-rmse:0.37115	validation-rmse:0.43896
# [11]	train-rmse:0.36361	validation-rmse:0.43594
# [12]	train-rmse:0.35850	validation-rmse:0.43558
# [13]	train-rmse:0.35365	validation-rmse:0.43394
# [14]	train-rmse:0.35025	validation-rmse:0.43349
# [15]	train-rmse:0.34666	validation-rmse:0.43362
# [16]	train-rmse:0.34459	validation-rmse:0.43378
# [17]	train-rmse:0.34128	validation-rmse:0.43405
# [18]	train-rmse:0.33822	validation-rmse:0.43391
# [19]	train-rmse:0.33709	validation-rmse:0.43374
# [20]	train-rmse:0.33553	validation-rmse:0.43376
# [21]	train-rmse:0.33243	validation-rmse:0.43453
# [22]	train-rmse:0.33031	validation-rmse:0.43510
# [23]	train-rmse:0.32815	validation-rmse:0.43601
# [24]	train-rmse:0.32670	validation-rmse:0.43592
# [25]	train-rmse:0.32268	validation-rmse:0.43683
# [26]	train-rmse:0.32085	validation-rmse:0.43678
# [27]	train-rmse:0.32035	validation-rmse:0.43681
# [28]	train-rmse:0.31879	validation-rmse:0.43719
# [29]	train-rmse:0.31653	validation-rmse:0.43739
# [30]	train-rmse:0.31475	validation-rmse:0.43752
# [31]	train-rmse:0.31392	validation-rmse:0.43782
# [32]	train-rmse:0.31263	validation-rmse:0.43761
# [33]	train-rmse:0.31155	validation-rmse:0.43764
# [34]	train-rmse:0.31054	validation-rmse:0.43793
# [35]	train-rmse:0.30960	validation-rmse:0.43784
# [36]	train-rmse:0.30813	validation-rmse:0.43828
# [37]	train-rmse:0.30573	validation-rmse:0.43891
# [38]	train-rmse:0.30406	validation-rmse:0.43924
# [39]	train-rmse:0.30257	validation-rmse:0.43946
# [40]	train-rmse:0.30202	validation-rmse:0.43968
# [41]	train-rmse:0.29908	validation-rmse:0.43978
# [42]	train-rmse:0.29772	validation-rmse:0.43998
# [43]	train-rmse:0.29594	validation-rmse:0.43969
# [44]	train-rmse:0.29420	validation-rmse:0.44009
# [45]	train-rmse:0.29126	validation-rmse:0.44024
# [46]	train-rmse:0.28929	validation-rmse:0.44041
# [47]	train-rmse:0.28821	validation-rmse:0.44101
# [48]	train-rmse:0.28629	validation-rmse:0.44096
# [49]	train-rmse:0.28528	validation-rmse:0.44142
# [50]	train-rmse:0.28456	validation-rmse:0.44140
# [51]	train-rmse:0.28309	validation-rmse:0.44160
# [52]	train-rmse:0.28144	validation-rmse:0.44109
# [53]	train-rmse:0.28095	validation-rmse:0.44152
# [54]	train-rmse:0.27894	validation-rmse:0.44191
# [55]	train-rmse:0.27618	validation-rmse:0.44225
# [56]	train-rmse:0.27373	validation-rmse:0.44265
# [57]	train-rmse:0.27156	validation-rmse:0.44310
# [58]	train-rmse:0.26938	validation-rmse:0.44276
# [59]	train-rmse:0.26797	validation-rmse:0.44282
# [60]	train-rmse:0.26768	validation-rmse:0.44290
# [61]	train-rmse:0.26749	validation-rmse:0.44285
# [62]	train-rmse:0.26536	validation-rmse:0.44311
# [63]	train-rmse:0.26420	validation-rmse:0.44329
# [64]	train-rmse:0.26236	validation-rmse:0.44360
# [65]	train-rmse:0.26174	validation-rmse:0.44352
# [66]	train-rmse:0.26155	validation-rmse:0.44360
# [67]	train-rmse:0.25959	validation-rmse:0.44410
# [68]	train-rmse:0.25719	validation-rmse:0.44487
# [69]	train-rmse:0.25665	validation-rmse:0.44476
# [70]	train-rmse:0.25489	validation-rmse:0.44531
# [71]	train-rmse:0.25277	validation-rmse:0.44563
# [72]	train-rmse:0.25084	validation-rmse:0.44632
# [73]	train-rmse:0.25017	validation-rmse:0.44649
# [74]	train-rmse:0.24985	validation-rmse:0.44661
# [75]	train-rmse:0.24792	validation-rmse:0.44628
# [76]	train-rmse:0.24643	validation-rmse:0.44671
# [77]	train-rmse:0.24565	validation-rmse:0.44667
# [78]	train-rmse:0.24421	validation-rmse:0.44633
# [79]	train-rmse:0.24291	validation-rmse:0.44663
# [80]	train-rmse:0.24254	validation-rmse:0.44689
# [81]	train-rmse:0.24246	validation-rmse:0.44692
# [82]	train-rmse:0.24112	validation-rmse:0.44705
# [83]	train-rmse:0.23963	validation-rmse:0.44721
# [84]	train-rmse:0.23803	validation-rmse:0.44704
# [85]	train-rmse:0.23644	validation-rmse:0.44749
# [86]	train-rmse:0.23533	validation-rmse:0.44757
# [87]	train-rmse:0.23481	validation-rmse:0.44756
# [88]	train-rmse:0.23428	validation-rmse:0.44778
# [89]	train-rmse:0.23267	validation-rmse:0.44809
# [90]	train-rmse:0.23193	validation-rmse:0.44839
# [91]	train-rmse:0.23149	validation-rmse:0.44844
# [92]	train-rmse:0.23040	validation-rmse:0.44863
# [93]	train-rmse:0.22891	validation-rmse:0.44896
# [94]	train-rmse:0.22701	validation-rmse:0.44922
# [95]	train-rmse:0.22475	validation-rmse:0.44904
# [96]	train-rmse:0.22336	validation-rmse:0.44954
# [97]	train-rmse:0.22131	validation-rmse:0.44979
# [98]	train-rmse:0.22013	validation-rmse:0.45040
# [99]	train-rmse:0.21950	validation-rmse:0.45018

# %% [markdown]
# ### The answer is 0.1
